# %% [markdown]
# ### This notebook aims to perform Exploratory Data Analysis (EDA) to gain a better understanding of the current Covid-19 situation through web-scraping live information about the virus on https://www.worldometers.info/coronavirus/
#
# Prepared by: Glendon Thaiw

# %% [markdown]
# ## Importing Requirements

# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from pprint import pprint
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import folium
from folium.features import DivIcon
import json
import re
import plotly.express as px
import plotly.graph_objs as go

# %% [markdown]
# ## Webcrawl with BeautifulSoup

# %%
url='https://www.worldometers.info/coronavirus/'
weburl=requests.get(url).content
soup=BeautifulSoup(weburl,'lxml')

# %%
my_table=soup.find('table',id='main_table_countries_today')
titles=[col.text for col in my_table.find('thead').find_all('th')]
titles[0]='Country'
data=[]
allrows=rows=my_table.find('tbody').find_all({'tr':'row'})
for row in allrows:
    stats=[col.text for col in row.find_all('td')]
    data.append(stats)
    
df=pd.DataFrame(data,columns=titles)
df['Country']=df['Country'].str.strip()
df.reset_index(drop=True).head()
# Out:
#    Country TotalCases NewCases TotalDeaths NewDeaths TotalRecovered  \
# 0    World  1,285,261  +12,399      70,344      +919        271,847
# 1      USA    336,851     +178      9,620         +4         17,977
# 2    Spain    135,032   +3,386     13,055       +414         40,437
# 3    Italy    128,948              15,887                    21,815
# 4  Germany    100,132       +9      1,584                    28,700
#
#   ActiveCases Serious,Critical Tot Cases/1M pop Deaths/1M pop TotalTests  \
# 0     943,070           45,994              165           9.0
# 1     309,254            8,702            1,018            29  1,772,369
# 2      81,540            6,931            2,888           279    355,000
# 3      91,246            3,977            2,133           263    691,461
# 4      69,848            3,936            1,195            19    918,460
#
#   Tests/\n1M pop\n
# 0
# 1            5,355
# 2            7,593
# 3           11,436
# 4           10,962

# %%
def FindCountry(country):
    return(df.loc[df['Country'].str.strip()==country])

# %%
def clean_table(col):
    df[col]=df[col].astype(str).str.strip().str.replace('+','').str.replace(',','')
    df[col]=df[col].astype(str).str.strip().str.replace('\n','')

    df[col] = pd.to_numeric(df[col]).fillna(0)
    return df

# %% [markdown]
# ## Cleaning the Table

# %%
colz=df.columns.drop('Country')

for c in colz:
    clean_table(c)

# %%
df
# Out:
#                     Country  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                     World     1285261   12399.0      70344.0      919.0
# 1                       USA      336851     178.0       9620.0        4.0
# 2                     Spain      135032    3386.0      13055.0      414.0
# 3                     Italy      128948       0.0      15887.0        0.0
# 4                   Germany      100132       9.0       1584.0        0.0
# 5                    France       92839       0.0       8078.0        0.0
# 6                      Iran       60500    2274.0       3739.0      136.0
# 7                        UK       47806       0.0       4934.0        0.0
# 8                    Turkey       27069       0.0        574.0        0.0
# 9               Switzerland       21282     182.0        734.0       19.0
# 10                  Belgium       20814    1123.0       1632.0      185.0
# 11              Netherlands       17851       0.0       1766.0        0.0
# 12                   Canada       15512       0.0        280.0        0.0
# 13                  Austria       12109      58.0        220.0       16.0
# 14                 Portugal       11730     452.0        311.0       16.0
# 15                   Brazil       11281      27.0        487.0        1.0
# 16                 S. Korea       10284      47.0        186.0        3.0
# 17                   Israel        8611     181.0         51.0        2.0
# 18                   Sweden        6830       0.0        401.0        0.0
# 19                   Russia        6343     954.0         47.0        2.0
# 20                Australia        5795      45.0         39.0        2.0
# 21                   Norway        5760      73.0         73.0        2.0
# 22                  Ireland        4994       0.0        158.0        0.0
# 23                  Denmark        4647     278.0        187.0        8.0
# 24                  Czechia        4591       4.0         72.0        5.0
# 25                    Chile        4471       0.0         34.0        0.0
# 26                    India        4314      25.0        118.0        0.0
# 27                   Poland        4201      99.0         98.0        4.0
# 28                  Romania        4057     193.0        157.0        6.0
# 29                 Malaysia        3793     131.0         62.0        1.0
# ..                      ...         ...       ...          ...        ...
# 181                   Nepal           9       0.0          0.0        0.0
# 182                    Chad           9       0.0          0.0        0.0
# 183                Eswatini           9       0.0          0.0        0.0
# 184                     CAR           8       0.0          0.0        0.0
# 185              Cabo Verde           7       0.0          1.0        0.0
# 186            Vatican City           7       0.0          0.0        0.0
# 187  St. Vincent Grenadines           7       0.0          0.0        0.0
# 188                 Somalia           7       0.0          0.0        0.0
# 189                Botswana           6       0.0          1.0        0.0
# 190              Mauritania           6       0.0          1.0        0.0
# 191               Nicaragua           6       0.0          1.0        0.0
# 192              Montserrat           6       0.0          0.0        0.0
# 193               St. Barth           6       0.0          0.0        0.0
# 194            Sierra Leone           6       0.0          0.0        0.0
# 195                  Belize           5       0.0          1.0        1.0
# 196        Turks and Caicos           5       0.0          1.0        0.0
# 197                  Bhutan           5       0.0          0.0        0.0
# 198                  Gambia           4       0.0          1.0        0.0
# 199                  Malawi           4       0.0          0.0        0.0
# 200          Western Sahara           4       0.0          0.0        0.0
# 201                Anguilla           3       0.0          0.0        0.0
# 202  British Virgin Islands           3       0.0          0.0        0.0
# 203                 Burundi           3       0.0          0.0        0.0
# 204   Caribbean Netherlands           2       0.0          0.0        0.0
# 205        Falkland Islands           2       0.0          0.0        0.0
# 206        Papua New Guinea           1       0.0          0.0        0.0
# 207   Saint Pierre Miquelon           1       0.0          0.0        0.0
# 208             South Sudan           1       0.0          0.0        0.0
# 209             Timor-Leste           1       0.0          0.0        0.0
# 210                   China       81708      39.0       3331.0        2.0
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0          271847.0       943070           45994.0            165.00
# 1           17977.0       309254            8702.0           1018.00
# 2           40437.0        81540            6931.0           2888.00
# 3           21815.0        91246            3977.0           2133.00
# 4           28700.0        69848            3936.0           1195.00
# 5           16183.0        68578            6838.0           1422.00
# 6           24236.0        32525            4083.0            720.00
# 7             135.0        42737            1559.0            704.00
# 8            1042.0        25453            1381.0            321.00
# 9            7298.0        13250             391.0           2459.00
# 10           3986.0        15196            1257.0           1796.00
# 11            250.0        15835            1385.0           1042.00
# 12           2942.0        12290             426.0            411.00
# 13           3463.0         8426             250.0           1344.00
# 14            140.0        11279             270.0           1150.00
# 15            127.0        10667             296.0             53.00
# 16           6598.0         3500              55.0            201.00
# 17            585.0         7975             141.0            995.00
# 18            205.0         6224             541.0            676.00
# 19            406.0         5890               8.0             43.00
# 20           2432.0         3324              96.0            227.00
# 21             32.0         5655              83.0           1062.00
# 22             25.0         4811             165.0           1011.00
# 23           1378.0         3082             144.0            802.00
# 24             96.0         4423              84.0            429.00
# 25            618.0         3819             307.0            234.00
# 26            328.0         3868               0.0              3.00
# 27            162.0         3941              50.0            111.00
# 28            406.0         3494             179.0            211.00
# 29           1241.0         2490             102.0            117.00
# ..              ...          ...               ...               ...
# 181             1.0            8               0.0              0.30
# 182             0.0            9               0.0              0.50
# 183             0.0            9               0.0              8.00
# 184             0.0            8               0.0              2.00
# 185             1.0            5               0.0             13.00
# 186             0.0            7               0.0           8739.00
# 187             1.0            6               0.0             63.00
# 188             1.0            6               0.0              0.40
# 189             0.0            5               0.0              3.00
# 190             2.0            3               0.0              1.00
# 191             0.0            5               0.0              0.90
# 192             0.0            6               0.0           1202.00
# 193             1.0            5               0.0            607.00
# 194             0.0            6               0.0              0.80
# 195             0.0            4               1.0             13.00
# 196             0.0            4               0.0            129.00
# 197             2.0            3               0.0              6.00
# 198             2.0            1               0.0              2.00
# 199             0.0            4               0.0              0.20
# 200             0.0            4               0.0              7.00
# 201             0.0            3               0.0            200.00
# 202             0.0            3               0.0             99.00
# 203             0.0            3               0.0              0.30
# 204             0.0            2               0.0             76.00
# 205             0.0            2               0.0            575.00
# 206             0.0            1               0.0              0.10
# 207             0.0            1               0.0            173.00
# 208             0.0            1               0.0              0.09
# 209             0.0            1               0.0              0.80
# 210         77078.0         1299             265.0             57.00
#
#      Deaths/1M pop  TotalTests  Tests/\n1M pop\n
# 0             9.00         0.0               0.0
# 1            29.00   1772369.0            5355.0
# 2           279.00    355000.0            7593.0
# 3           263.00    691461.0           11436.0
# 4            19.00    918460.0           10962.0
# 5           124.00    224254.0            3436.0
# 6            45.00    186000.0            2214.0
# 7            73.00    195524.0            2880.0
# 8             7.00    181445.0            2151.0
# 9            85.00    158000.0           18256.0
# 10          141.00     70000.0            6040.0
# 11          103.00     75415.0            4401.0
# 12            7.00    330901.0            8767.0
# 13           24.00    111296.0           12357.0
# 14           31.00     91794.0            9002.0
# 15            2.00     54824.0             258.0
# 16            4.00    461233.0            8996.0
# 17            6.00    109724.0           12677.0
# 18           40.00     36900.0            3654.0
# 19            0.30    758000.0            5194.0
# 20            2.00    302000.0           11843.0
# 21           13.00    108709.0           20052.0
# 22           32.00     30213.0            6119.0
# 23           32.00     49249.0            8503.0
# 24            7.00     85014.0            7939.0
# 25            2.00     51956.0            2718.0
# 26            0.09    140293.0             102.0
# 27            3.00     80757.0            2134.0
# 28            8.00     40987.0            2131.0
# 29            2.00     55566.0            1717.0
# ..             ...         ...               ...
# 181           0.00      1656.0              57.0
# 182           0.00         0.0               0.0
# 183           0.00         0.0               0.0
# 184           0.00         0.0               0.0
# 185           2.00         0.0               0.0
# 186           0.00         0.0               0.0
# 187           0.00         0.0               0.0
# 188           0.00         0.0               0.0
# 189           0.40       966.0             411.0
# 190           0.20        67.0              14.0
# 191           0.20         0.0               0.0
# 192           0.00         0.0               0.0
# 193           0.00         0.0               0.0
# 194           0.00         0.0               0.0
# 195           3.00       102.0             257.0
# 196          26.00         0.0               0.0
# 197           0.00         0.0               0.0
# 198           0.40         0.0               0.0
# 199           0.00         0.0               0.0
# 200           0.00         0.0               0.0
# 201           0.00         0.0               0.0
# 202           0.00         0.0               0.0
# 203           0.00         0.0               0.0
# 204           0.00        10.0             381.0
# 205           0.00         0.0               0.0
# 206           0.00        72.0               8.0
# 207           0.00         0.0               0.0
# 208           0.00         0.0               0.0
# 209           0.00         0.0               0.0
# 210           2.00         0.0               0.0
#
# [211 rows x 12 columns]

# %%
df.columns=['Country','TotalCases','NewCases','TotalDeaths','NewDeaths','TotalRecovered','ActiveCases','Serious','TotalCasesPer1M','TotalDeathsPer1M','TotalTests','TestsPer1M']

# %%
df=df[1:]

# %% [markdown]
# ### Adding Additional Statistics

# %%
df['Mortality_Rate']=(df['TotalDeaths']/df['TotalCases'])*100
df['Recovery_Rate']=(df['TotalRecovered']/df['TotalCases'])*100
df['Active_Rate']=(df['ActiveCases']/df['TotalCases'])*100
df['MortalityPer1M']=df['Mortality_Rate']*df['TotalCasesPer1M']/100
df['RecoveryPer1M']=df['Recovery_Rate']*df['TotalCasesPer1M']/100
df['Recovery_to_Mortality_Ratio']=df['Recovery_Rate'] / df['Mortality_Rate']
df['Recovery_Odds']=df['Recovery_to_Mortality_Ratio']/(1+df['Recovery_to_Mortality_Ratio'])*100

World_Mortality=df['TotalDeaths'].sum()/df['TotalCases'].sum()
World_Recovery=df['TotalRecovered'].sum()/df['TotalCases'].sum()
World_Active=df['ActiveCases'].sum()/df['TotalCases'].sum()
totalrecovered=df['TotalRecovered'].sum()
totaldeath=df['TotalDeaths'].sum()

print('Based on the current information:\n')
print('Total World Mortality Rate: {:0.2%}\nTotal World Recovery Rate: {:0.2%}\nTotal World Active Rate: {:0.2%}'.format(World_Mortality,World_Recovery,World_Active))
print('\n')
print("The Recovery to Mortality Ratio is {:0.1f}.".format(World_Recovery/World_Mortality))

print("This means that for every 1 mortality, {:0.1f} will recover.".format(World_Recovery/World_Mortality))

oddsforsurvival = (totalrecovered/(totalrecovered+totaldeath))

print("A Patient\'s odds for survival is {:0.2%}".format((oddsforsurvival)))
# Out:
# Based on the current information:
#
# Total World Mortality Rate: 5.47%
# Total World Recovery Rate: 21.15%
# Total World Active Rate: 73.38%
#
#
# The Recovery to Mortality Ratio is 3.9.
# This means that for every 1 mortality, 3.9 will recover.
# A Patient's odds for survival is 79.44%
# /Users/glendont/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/glendont/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/glendont/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/glendont/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/glendont/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/glendont/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/glendont/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Removing entries with less than 30 Total Cases

# %%
df=df.sort_values(by=['TotalCases'], ascending=True)
df=df.reset_index()
df=df.drop(['index'],axis= 1)

# %%
df=df.loc[77:]
df.head()
# Out:
#       Country  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 77      Egypt        1173       0.0         78.0        0.0           247.0
# 78    Croatia        1182       0.0         15.0        0.0           125.0
# 79  Singapore        1309       0.0          6.0        0.0           320.0
# 80    Ukraine        1319      11.0         38.0        1.0            28.0
# 81    Algeria        1320       0.0        152.0        0.0            90.0
#
#     ActiveCases  Serious  TotalCasesPer1M  TotalDeathsPer1M  TotalTests  \
# 77          848      0.0             11.0               0.8     25000.0
# 78         1042     39.0            288.0               4.0     10874.0
# 79          983     25.0            224.0               1.0     40000.0
# 80         1253     16.0             30.0               0.9      5864.0
# 81         1078     46.0             30.0               3.0      3359.0
#
#     TestsPer1M  Mortality_Rate  Recovery_Rate  Active_Rate  MortalityPer1M  \
# 77       244.0        6.649616      21.057118    72.293265        0.731458
# 78      2649.0        1.269036      10.575296    88.155668        3.654822
# 79      6837.0        0.458365      24.446142    75.095493        1.026738
# 80       134.0        2.880970       2.122820    94.996209        0.864291
# 81        77.0       11.515152       6.818182    81.666667        3.454545
#
#     RecoveryPer1M  Recovery_to_Mortality_Ratio  Recovery_Odds
# 77       2.316283                     3.166667      76.000000
# 78      30.456853                     8.333333      89.285714
# 79      54.759358                    53.333333      98.159509
# 80       0.636846                     0.736842      42.424242
# 81       2.045455                     0.592105      37.190083

# %% [markdown]
# ## Final Table

# %%
df.head()
# Out:
#       Country  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 77      Egypt        1173       0.0         78.0        0.0           247.0
# 78    Croatia        1182       0.0         15.0        0.0           125.0
# 79  Singapore        1309       0.0          6.0        0.0           320.0
# 80    Ukraine        1319      11.0         38.0        1.0            28.0
# 81    Algeria        1320       0.0        152.0        0.0            90.0
#
#     ActiveCases  Serious  TotalCasesPer1M  TotalDeathsPer1M  TotalTests  \
# 77          848      0.0             11.0               0.8     25000.0
# 78         1042     39.0            288.0               4.0     10874.0
# 79          983     25.0            224.0               1.0     40000.0
# 80         1253     16.0             30.0               0.9      5864.0
# 81         1078     46.0             30.0               3.0      3359.0
#
#     TestsPer1M  Mortality_Rate  Recovery_Rate  Active_Rate  MortalityPer1M  \
# 77       244.0        6.649616      21.057118    72.293265        0.731458
# 78      2649.0        1.269036      10.575296    88.155668        3.654822
# 79      6837.0        0.458365      24.446142    75.095493        1.026738
# 80       134.0        2.880970       2.122820    94.996209        0.864291
# 81        77.0       11.515152       6.818182    81.666667        3.454545
#
#     RecoveryPer1M  Recovery_to_Mortality_Ratio  Recovery_Odds
# 77       2.316283                     3.166667      76.000000
# 78      30.456853                     8.333333      89.285714
# 79      54.759358                    53.333333      98.159509
# 80       0.636846                     0.736842      42.424242
# 81       2.045455                     0.592105      37.190083

# %% [markdown]
# ## Looking at the Top Cases

# %%
top=df.sort_values(by=['TotalCases'], ascending=False).head()
top.head()
# Out:
#      Country  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 132      USA      336851     178.0       9620.0        4.0         17977.0
# 131    Spain      135032    3386.0      13055.0      414.0         40437.0
# 130    Italy      128948       0.0      15887.0        0.0         21815.0
# 129  Germany      100132       9.0       1584.0        0.0         28700.0
# 128   France       92839       0.0       8078.0        0.0         16183.0
#
#      ActiveCases  Serious  TotalCasesPer1M  TotalDeathsPer1M  TotalTests  \
# 132       309254   8702.0           1018.0              29.0   1772369.0
# 131        81540   6931.0           2888.0             279.0    355000.0
# 130        91246   3977.0           2133.0             263.0    691461.0
# 129        69848   3936.0           1195.0              19.0    918460.0
# 128        68578   6838.0           1422.0             124.0    224254.0
#
#      TestsPer1M  Mortality_Rate  Recovery_Rate  Active_Rate  MortalityPer1M  \
# 132      5355.0        2.855862       5.336781    91.807357       29.072676
# 131      7593.0        9.668079      29.946235    60.385686      279.214112
# 130     11436.0       12.320470      16.917672    70.761857      262.795631
# 129     10962.0        1.581912      28.662166    69.755922       18.903847
# 128      3436.0        8.701085      17.431252    73.867663      123.729424
#
#      RecoveryPer1M  Recovery_to_Mortality_Ratio  Recovery_Odds
# 132      54.328430                     1.868711      65.141139
# 131     864.847266                     3.097434      75.594481
# 130     360.853949                     1.373135      57.861652
# 129     342.512883                    18.118687      94.769515
# 128     247.872403                     2.003342      66.703763

# %%
colz2=df.columns.drop('Country')
def getOther(col):
    df_other=df[col].sum()-top[col].sum()
    return df_other

# %%
def getRatio(percent,mycol):
    df[percent]=df[mycol]/df[mycol].sum()
    top=df.sort_values(by=[mycol],ascending=False)
    return top
top.head()
# Out:
#      Country  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 132      USA      336851     178.0       9620.0        4.0         17977.0
# 131    Spain      135032    3386.0      13055.0      414.0         40437.0
# 130    Italy      128948       0.0      15887.0        0.0         21815.0
# 129  Germany      100132       9.0       1584.0        0.0         28700.0
# 128   France       92839       0.0       8078.0        0.0         16183.0
#
#      ActiveCases  Serious  TotalCasesPer1M  TotalDeathsPer1M  TotalTests  \
# 132       309254   8702.0           1018.0              29.0   1772369.0
# 131        81540   6931.0           2888.0             279.0    355000.0
# 130        91246   3977.0           2133.0             263.0    691461.0
# 129        69848   3936.0           1195.0              19.0    918460.0
# 128        68578   6838.0           1422.0             124.0    224254.0
#
#      TestsPer1M  Mortality_Rate  Recovery_Rate  Active_Rate  MortalityPer1M  \
# 132      5355.0        2.855862       5.336781    91.807357       29.072676
# 131      7593.0        9.668079      29.946235    60.385686      279.214112
# 130     11436.0       12.320470      16.917672    70.761857      262.795631
# 129     10962.0        1.581912      28.662166    69.755922       18.903847
# 128      3436.0        8.701085      17.431252    73.867663      123.729424
#
#      RecoveryPer1M  Recovery_to_Mortality_Ratio  Recovery_Odds
# 132      54.328430                     1.868711      65.141139
# 131     864.847266                     3.097434      75.594481
# 130     360.853949                     1.373135      57.861652
# 129     342.512883                    18.118687      94.769515
# 128     247.872403                     2.003342      66.703763

# %%
lst=[getOther(c) for c in colz2]
df_other=pd.DataFrame(lst).T
df_other.columns=colz2
df_other['Country']='Other'
top=top.append(df_other)
top=top.reset_index(drop=True)
top['Mortality_Rate']=(top['TotalDeaths']/top['TotalCases'])*100
top['Recovery_Rate']=(top['TotalRecovered']/top['TotalCases'])*100
top['Active_Rate']=(top['ActiveCases']/top['TotalCases'])*100
top['MortalityPer1M']=top['Mortality_Rate']*top['TotalCasesPer1M']/100
top['RecoveryPer1M']=top['Recovery_Rate']*top['TotalCasesPer1M']/100
top['Recovery_to_Mortality_Ratio']=top['Recovery_Rate'] / top['Mortality_Rate']
top['Recovery_Odds']=top['Recovery_to_Mortality_Ratio']/(1+top['Recovery_to_Mortality_Ratio'])*100
top=top.sort_values(by=['Recovery_Odds'],ascending=False)
top
# Out:
# /Users/glendont/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6701: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#    ActiveCases  Active_Rate  Country  MortalityPer1M  Mortality_Rate  \
# 3      69848.0    69.755922  Germany       18.903847        1.581912
# 5     296853.0    64.472993    Other     1311.849284        4.634364
# 1      81540.0    60.385686    Spain      279.214112        9.668079
# 4      68578.0    73.867663   France      123.729424        8.701085
# 0     309254.0    91.807357      USA       29.072676        2.855862
# 2      91246.0    70.761857    Italy      262.795631       12.320470
#
#    NewCases  NewDeaths  RecoveryPer1M  Recovery_Odds  Recovery_Rate  \
# 3       9.0        0.0     342.512883      94.769515      28.662166
# 5    7749.0      462.0    8744.780690      86.955379      30.892644
# 1    3386.0      414.0     864.847266      75.594481      29.946235
# 4       0.0        0.0     247.872403      66.703763      17.431252
# 0     178.0        4.0      54.328430      65.141139       5.336781
# 2       0.0        0.0     360.853949      57.861652      16.917672
#
#    Recovery_to_Mortality_Ratio  Serious  TestsPer1M  TotalCases  \
# 3                    18.118687   3936.0     10962.0    100132.0
# 5                     6.665995  14983.0    332807.0    460430.0
# 1                     3.097434   6931.0      7593.0    135032.0
# 4                     2.003342   6838.0      3436.0     92839.0
# 0                     1.868711   8702.0      5355.0    336851.0
# 2                     1.373135   3977.0     11436.0    128948.0
#
#    TotalCasesPer1M  TotalDeaths  TotalDeathsPer1M  TotalRecovered  TotalTests
# 3           1195.0       1584.0             19.00         28700.0    918460.0
# 5          28307.0      21338.0            811.79        142239.0   4511705.0
# 1           2888.0      13055.0            279.00         40437.0    355000.0
# 4           1422.0       8078.0            124.00         16183.0    224254.0
# 0           1018.0       9620.0             29.00         17977.0   1772369.0
# 2           2133.0      15887.0            263.00         21815.0    691461.0

# %%
df_other
# Out:
#    TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  ActiveCases  \
# 0    460430.0    7749.0      21338.0      462.0        142239.0     296853.0
#
#    Serious  TotalCasesPer1M  TotalDeathsPer1M  TotalTests  TestsPer1M  \
# 0  14983.0          28307.0            811.79   4511705.0    332807.0
#
#    Mortality_Rate  Recovery_Rate  Active_Rate  MortalityPer1M  RecoveryPer1M  \
# 0      164.418954     810.585597   4124.99545      808.808829    5059.383907
#
#    Recovery_to_Mortality_Ratio  Recovery_Odds Country
# 0                   583.970242    3518.301597   Other

# %%
top.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col1 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col6 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col7 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col8 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col9 {
#             background-color:  #920a13;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col10 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col11 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col12 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col13 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col14 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col15 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col16 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col17 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row0_col18 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col0 {
#             background-color:  #800610;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col1 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col4 {
#             background-color:  #fcb095;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col6 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col7 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col8 {
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col9 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col10 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col11 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col12 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col13 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col14 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col15 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col16 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col17 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row1_col18 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col0 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col3 {
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col4 {
#             background-color:  #ca181d;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col5 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col6 {
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col7 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col8 {
#             background-color:  #fb7151;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col9 {
#             background-color:  #79040f;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col10 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col11 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col12 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col13 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col14 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col15 {
#             background-color:  #f34c37;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col16 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col17 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row2_col18 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row3_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row3_col1 {
#             background-color:  #fc8161;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row3_col3 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row3_col4 {
#             background-color:  #e43027;
#             color:  #f1f1f1;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row3_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f7a8c34_77f9_11ea_9705_acde48001122row3_col6 {
#             background-color:  #fff5f0;

# %% [markdown]
# ### Total Cases

# %%
labels=top['Country']
sizes=top['TotalCases']
colors=['lightskyblue','yellowgreen','lightcoral','gold','lightgreen','orange']

plt.pie(x=sizes,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False,startangle=90)
plt.gcf().set_size_inches(10,10)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Active Cases

# %%
labels=top['Country']
sizes=top['ActiveCases']
colors=['lightskyblue','yellowgreen','lightcoral','gold','lightgreen','orange']

plt.pie(x=sizes,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False,startangle=90)
plt.gcf().set_size_inches(10,10)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Serious Cases

# %%
labels=top['Country']
sizes=top['Serious']
colors=['lightskyblue','yellowgreen','lightcoral','gold','lightgreen','orange']

plt.pie(x=sizes,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False,startangle=90)
plt.gcf().set_size_inches(10,10)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Recovery Rate Analysis

# %%
f,ax = plt.subplots(figsize=(20,10))
sns.set_color_codes("pastel")
sns.barplot(x="Recovery_Rate", y="Country",data=top, label='Recovered',color="b")

sns.set_color_codes("muted")
sns.barplot(x="Mortality_Rate", y="Country",data=top, label='Death',color="b")

ax.legend(ncol=2,loc="lower right",frameon=True)
ax.set(xlim=(0,85),ylabel="Country",xlabel="Recover Rates vs Mortality")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Recovery Odds

# %%
top=df.sort_values(by=['Recovery_Odds'], ascending=False).head()
f,ax = plt.subplots(figsize=(15,10))
ax=sns.barplot(x="Country", y="Recovery_Odds",data=top, label='Recovery Odds',color="b")

# %%
df[df['Country']=='Singapore']
# Out:
#       Country  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 79  Singapore        1309       0.0          6.0        0.0           320.0
#
#     ActiveCases  Serious  TotalCasesPer1M  TotalDeathsPer1M  TotalTests  \
# 79          983     25.0            224.0               1.0     40000.0
#
#     TestsPer1M  Mortality_Rate  Recovery_Rate  Active_Rate  MortalityPer1M  \
# 79      6837.0        0.458365      24.446142    75.095493        1.026738
#
#     RecoveryPer1M  Recovery_to_Mortality_Ratio  Recovery_Odds
# 79      54.759358                    53.333333      98.159509

# %% [markdown]
# ## Map

# %%
import geopandas as gpd

# Access built-in Natural Earth data via GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Get a list (dataframe) of country centroids
centroids = world.centroid
centroid_list = pd.concat([world.name, centroids], axis=1)

# Plot the results
base = world.plot(column = 'name', cmap = 'Blues')
centroids.plot(ax = base, marker = 'o', color = 'red', markersize = 5)
centroid_list.columns=['Country','latlng']

# %%
df_merged_lng=pd.merge(df,centroid_list,on='Country')
df_merged_lng[df_merged_lng['Country']=='Singapore']
# Out:
# Empty DataFrame
# Columns: [Country, TotalCases, NewCases, TotalDeaths, NewDeaths, TotalRecovered, ActiveCases, Serious, TotalCasesPer1M, TotalDeathsPer1M, TotalTests, TestsPer1M, Mortality_Rate, Recovery_Rate, Active_Rate, MortalityPer1M, RecoveryPer1M, Recovery_to_Mortality_Ratio, Recovery_Odds, latlng]
# Index: []

# %%
m = folium.Map(
    location=[35,56],
    zoom_start=2,
)

def getMarkers(df):
    for i in range(len(df)):
        string='Country: {}'.format(df.loc[i]['Country'])
        if df.loc[i]['Recovery_Odds']>75:
            folium.Marker(
            location=((df['latlng'][i]).y,df['latlng'][i].x),
                popup=string,
                color="green",
                icon=folium.Icon(color='green',icon='')).add_to(m)
    
        elif (df.loc[i]['Recovery_Odds']>25 and df.loc[i]['Recovery_Odds']<75):
            folium.Marker(
            location=((df['latlng'][i]).y,df['latlng'][i].x),
                popup=string,
                color="yellow",
                icon=folium.Icon(color='orange',icon='')).add_to(m)

        elif df.loc[i]['Recovery_Odds']<25:
            folium.Marker(
            location=((df['latlng'][i]).y,df['latlng'][i].x),
                popup=string,
                color="green",
                icon=folium.Icon(color='red',icon='')).add_to(m)

getMarkers(df_merged_lng)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# ### Getting all Recoveries

# %%
url2='https://www.worldometers.info/coronavirus/coronavirus-cases/'
weburl2=requests.get(url2).content
soup2 = BeautifulSoup(weburl2,'lxml')
cured = soup2.find('div', id='cured-total').find('script',type='text/javascript').text
cat = re.search(r'{ categories:(.*?) yAxis:',cured).group(1)
categories = re.search(r'(.*?)]',cat).group(1).replace('[','').replace(']','').replace('"','').replace(' ','').split(',')
dta=re.search(r' data:(.*?), responsive:', cured).group(1)
data=re.search(r' (.*?)}]',dta).group(1).replace('[','').replace(']','').replace('"','').replace(' ','').split(',')
final_data =[int(d) for d in data] 
d={
    'Date':categories,
    'Recovery':final_data
}
df_rec=pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-19240ed69a0a> in <module>
#       3 soup2 = BeautifulSoup(weburl2,'lxml')
#       4 cured = soup2.find('div', id='cured-total').find('script',type='text/javascript').text
# ----> 5 cat = re.search(r'{ categories:(.*?) yAxis:',cured).group(1)
#       6 categories = re.search(r'(.*?)]',cat).group(1).replace('[','').replace(']','').replace('"','').replace(' ','').split(',')
#       7 dta=re.search(r' data:(.*?), responsive:', cured).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
fig = px.line(df_rec, x="Date", y="Recovery",title='Recovery Over Time')
fig.show()

# %% [markdown]
# ### Getting all Deaths

# %%
url3='https://www.worldometers.info/coronavirus/coronavirus-death-toll/'
weburl3=requests.get(url3).content
soup3 = BeautifulSoup(weburl3,'lxml')

dead=soup3.find_all('script',type='text/javascript')[9].text

cat3 = re.search(r'{ categories:(.*?) yAxis:',dead).group(1)
categories3 = re.search(r'(.*?)]',cat3).group(1).replace('[','').replace(']','').replace('"','').replace(' ','').split(',')
dta3=re.search(r' data:(.*?), responsive:', dead).group(1)
data3=re.search(r' (.*?)}]',dta3).group(1).replace('[','').replace(']','').replace('"','').replace(' ','').split(',')
final_data3 =[int(d) for d in data3] 
d3={
    'Date':categories3,
    'Dead':final_data3
}
df_dd=pd.DataFrame(d3)
df_dd=df_dd.loc[11:]

# %%
fig = px.line(df_dd, x="Date", y="Dead",title='Death Over Time')
fig.show()

# %%
df_rec_dead=pd.merge(df_rec,df_dd,on='Date')
df_rec_dead['World_Recovery_Odds']=df_rec_dead['Recovery']/(df_rec_dead['Recovery']+df_rec_dead['Dead'])*100
df_rec_dead.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-53201ac787ce> in <module>
# ----> 1 df_rec_dead=pd.merge(df_rec,df_dd,on='Date')
#       2 df_rec_dead['World_Recovery_Odds']=df_rec_dead['Recovery']/(df_rec_dead['Recovery']+df_rec_dead['Dead'])*100
#       3 df_rec_dead.head()
#
# NameError: name 'df_rec' is not defined

# %%
fig = px.line(df_rec_dead, x="Date", y="World_Recovery_Odds",title='Recovery Over Time')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-119b2ccdce6e> in <module>
# ----> 1 fig = px.line(df_rec_dead, x="Date", y="World_Recovery_Odds",title='Recovery Over Time')
#       2 fig.show()
#
# NameError: name 'df_rec_dead' is not defined

# %%
fig = go.Figure()
# Create and style traces
Date=df_rec_dead['Date']
Dead=df_rec_dead['Dead']
Recover=df_rec_dead['Recovery']
Recover_rate=df_rec_dead['World_Recovery_Odds']

fig = px.line(df_rec_dead, x="Date", y="World_Recovery_Odds",title='Recovery Odds Over Time')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f564bf773236> in <module>
#       1 fig = go.Figure()
#       2 # Create and style traces
# ----> 3 Date=df_rec_dead['Date']
#       4 Dead=df_rec_dead['Dead']
#       5 Recover=df_rec_dead['Recovery']
#
# NameError: name 'df_rec_dead' is not defined

# %% [markdown]
# ### Life Expectancy

# %%
df_ages=pd.read_csv('Life Expectancy Data.csv')
df_ages=df_ages[df_ages['Year']==2015]
df_ages=df_ages.drop(['percentage expenditure','Total expenditure','Year','Income composition of resources','Alcohol','Status','Polio','under-five deaths ',' thinness 5-9 years',' thinness  1-19 years','Schooling'],axis=1)

# %%
df_ages.head()
# Out:
#                 Country  Life expectancy   Adult Mortality  infant deaths  \
# 0           Afghanistan              65.0            263.0             62
# 16              Albania              77.8             74.0              0
# 32              Algeria              75.6             19.0             21
# 48               Angola              52.4            335.0             66
# 64  Antigua and Barbuda              76.4             13.0              0
#
#     Hepatitis B  Measles    BMI   Diphtheria    HIV/AIDS           GDP  \
# 0          65.0      1154   19.1         65.0        0.1    584.259210
# 16         99.0         0   58.0         99.0        0.1   3954.227830
# 32         95.0        63   59.5         95.0        0.1   4132.762920
# 48         64.0       118   23.3         64.0        1.9   3695.793748
# 64         99.0         0   47.7         99.0        0.2  13566.954100
#
#     Population
# 0   33736494.0
# 16     28873.0
# 32  39871528.0
# 48   2785935.0
# 64         NaN

# %%
df_age_recovery = pd.merge(df_ages,df, on='Country')
df_age_recovery.sort_values(by=['Country'],ascending=True)
df_age_recovery=df_age_recovery.drop(['Recovery_to_Mortality_Ratio','RecoveryPer1M','MortalityPer1M','NewDeaths'],axis=1)

# %%
df_age_recovery.corr()
# Out:
#                   Life expectancy   Adult Mortality  infant deaths  \
# Life expectancy           1.000000        -0.828172      -0.459173
# Adult Mortality          -0.828172         1.000000       0.319290
# infant deaths            -0.459173         0.319290       1.000000
# Hepatitis B               0.374377        -0.415408      -0.009661
# Measles                  -0.313544         0.210676       0.894900
#  BMI                      0.465941        -0.394929      -0.396204
# Diphtheria                0.483530        -0.513317      -0.077383
#  HIV/AIDS                -0.464328         0.618733       0.032687
# GDP                       0.409729        -0.335813      -0.183952
# Population               -0.250251         0.094412       0.024449
# TotalCases                0.260499        -0.264582      -0.042175
# NewCases                  0.134497        -0.096265      -0.047847
# TotalDeaths               0.240161        -0.207605      -0.054789
# TotalRecovered            0.120210        -0.169214       0.052701
# ActiveCases               0.292318        -0.272781      -0.090094
# Serious                   0.285454        -0.248939      -0.099622
# TotalCasesPer1M           0.491042        -0.426385      -0.176951
# TotalDeathsPer1M          0.367214        -0.298833      -0.122815
# TotalTests                0.286010        -0.262179      -0.021458
# TestsPer1M                0.402585        -0.361107      -0.144818
# Mortality_Rate            0.056675        -0.113506      -0.027452
# Recovery_Rate             0.189149        -0.176073       0.000624
# Active_Rate              -0.197756         0.194870       0.004254
# Recovery_Odds             0.137310        -0.086280       0.046590
#
#                   Hepatitis B  Measles       BMI   Diphtheria    HIV/AIDS  \
# Life expectancy      0.374377 -0.313544  0.465941     0.483530  -0.464328
# Adult Mortality     -0.415408  0.210676 -0.394929    -0.513317   0.618733
# infant deaths       -0.009661  0.894900 -0.396204    -0.077383   0.032687
# Hepatitis B          1.000000  0.064069  0.277835     0.834665  -0.061579
# Measles              0.064069  1.000000 -0.356993     0.015639  -0.003164
#  BMI                 0.277835 -0.356993  1.000000     0.162329  -0.030821
# Diphtheria           0.834665  0.015639  0.162329     1.000000  -0.110854
#  HIV/AIDS           -0.061579 -0.003164 -0.030821    -0.110854   1.000000
# GDP                  0.190070 -0.152666  0.181983     0.235069  -0.085484
# Population          -0.004242  0.044815 -0.087597    -0.062081  -0.010139
# TotalCases           0.162097  0.075589  0.155149     0.163998  -0.073816
# NewCases             0.052163 -0.049536  0.086362     0.033047  -0.049171
# TotalDeaths          0.132094  0.000460  0.154136     0.116186  -0.054941
# TotalRecovered       0.151605  0.298990 -0.021840     0.137308  -0.055296
# ActiveCases          0.135968 -0.070083  0.230867     0.150650  -0.071486
# Serious              0.129262 -0.071657  0.220921     0.152688  -0.067195
# TotalCasesPer1M      0.218030 -0.144027  0.297920     0.227323  -0.107004
# TotalDeathsPer1M     0.162094 -0.101290  0.242776     0.166417  -0.076490
# TotalTests           0.102177  0.000191  0.213536     0.150118  -0.044778
# TestsPer1M           0.212869 -0.119810  0.235134     0.173341  -0.079566
# Mortality_Rate      -0.011828  0.015779  0.076840    -0.014758  -0.124688
# Recovery_Rate        0.085474  0.221785 -0.103325     0.071696  -0.102798
# Active_Rate         -0.082699 -0.222879  0.088888    -0.068524   0.124145
# Recovery_Odds        0.136702  0.072162 -0.054875     0.175346   0.083488
#
#                        GDP  Population  ...  ActiveCases   Serious  \
# Life expectancy   0.409729   -0.250251  ...     0.292318  0.285454
# Adult Mortality  -0.335813    0.094412  ...    -0.272781 -0.248939
# infant deaths    -0.183952    0.024449  ...    -0.090094 -0.099622
# Hepatitis B       0.190070   -0.004242  ...     0.135968  0.129262
# Measles          -0.152666    0.044815  ...    -0.070083 -0.071657
#  BMI              0.181983   -0.087597  ...     0.230867  0.220921
# Diphtheria        0.235069   -0.062081  ...     0.150650  0.152688
#  HIV/AIDS        -0.085484   -0.010139  ...    -0.071486 -0.067195
# GDP               1.000000   -0.011565  ...     0.190140  0.232722
# Population       -0.011565    1.000000  ...     0.100038  0.093759
# TotalCases        0.144155    0.072698  ...     0.929524  0.889501
# NewCases          0.023368    0.101713  ...     0.445882  0.548247
# TotalDeaths       0.048764   -0.002889  ...     0.883225  0.837201
# TotalRecovered    0.040692    0.020249  ...     0.491672  0.504189
# ActiveCases       0.190140    0.100038  ...     1.000000  0.937063
# Serious           0.232722    0.093759  ...     0.937063  1.000000
# TotalCasesPer1M   0.033993   -0.133456  ...     0.402227  0.382287
# TotalDeathsPer1M  0.049345   -0.042993  ...     0.809584  0.785707
# TotalTests        0.324719    0.124606  ...     0.823177  0.650246
# TestsPer1M        0.087437   -0.144937  ...     0.054767  0.013185
# Mortality_Rate   -0.156344    0.249593  ...     0.503051  0.517794
# Recovery_Rate     0.110455   -0.054753  ...     0.089764  0.119890
# Active_Rate      -0.082359    0.011547  ...    -0.178386 -0.210898
# Recovery_Odds     0.284881   -0.041290  ...    -0.007403  0.000191
#
#                   TotalCasesPer1M  TotalDeathsPer1M  TotalTests  TestsPer1M  \
# Life expectancy          0.491042          0.367214    0.286010    0.402585
# Adult Mortality         -0.426385         -0.298833   -0.262179   -0.361107
# infant deaths           -0.176951         -0.122815   -0.021458   -0.144818
# Hepatitis B              0.218030          0.162094    0.102177    0.212869
# Measles                 -0.144027         -0.101290    0.000191   -0.119810
#  BMI                     0.297920          0.242776    0.213536    0.235134
# Diphtheria               0.227323          0.166417    0.150118    0.173341
#  HIV/AIDS               -0.107004         -0.076490   -0.044778   -0.079566
# GDP                      0.033993          0.049345    0.324719    0.087437
# Population              -0.133456         -0.042993    0.124606   -0.144937
# TotalCases               0.368355          0.771504    0.746664    0.030228
# NewCases                 0.328191          0.642328    0.171650   -0.002856
# TotalDeaths              0.385017          0.900307    0.579818    0.025357
# TotalRecovered           0.177112          0.401486    0.393547   -0.018816
# ActiveCases              0.402227          0.809584    0.823177    0.054767
# Serious                  0.382287          0.785707    0.650246    0.013185
# TotalCasesPer1M          1.000000          0.574646    0.280199    0.827668
# TotalDeathsPer1M         0.574646          1.000000    0.494989    0.132667
# TotalTests               0.280199          0.494989    1.000000    0.119843
# TestsPer1M               0.827668          0.132667    0.119843    1.000000
# Mortality_Rate           0.109464          0.651727    0.190562   -0.228218
# Recovery_Rate            0.130134          0.084507    0.148136    0.128671
# Active_Rate             -0.148567         -0.199566   -0.180829   -0.087162
# Recovery_Odds            0.133719         -0.091692    0.148335    0.236323
#
#                   Mortality_Rate  Recovery_Rate  Active_Rate  Recovery_Odds
# Life expectancy         0.056675       0.189149    -0.197756       0.137310
# Adult Mortality        -0.113506      -0.176073     0.194870      -0.086280
# infant deaths          -0.027452       0.000624     0.004254       0.046590
# Hepatitis B            -0.011828       0.085474    -0.082699       0.136702
# Measles                 0.015779       0.221785    -0.222879       0.072162
#  BMI                    0.076840      -0.103325     0.088888      -0.054875
# Diphtheria             -0.014758       0.071696    -0.068524       0.175346
#  HIV/AIDS              -0.124688      -0.102798     0.124145       0.083488
# GDP                    -0.156344       0.110455    -0.082359       0.284881
# Population              0.249593      -0.054753     0.011547      -0.041290
# TotalCases              0.490015       0.357112    -0.441362       0.070282
# NewCases                0.334408       0.116236    -0.174713       0.014904
# TotalDeaths             0.624919       0.186714    -0.296227      -0.028423
# TotalRecovered          0.260375       0.695817    -0.736689       0.192356
# ActiveCases             0.503051       0.089764    -0.178386      -0.007403
# Serious                 0.517794       0.119890    -0.210898       0.000191
# TotalCasesPer1M         0.109464       0.130134    -0.148567       0.133719
# TotalDeathsPer1M        0.651727       0.084507    -0.199566      -0.091692
# TotalTests              0.190562       0.148136    -0.180829       0.148335
# TestsPer1M             -0.228218       0.128671    -0.087162       0.236323
# Mortality_Rate          1.000000      -0.045941    -0.131956      -0.450787
# Recovery_Rate          -0.045941       1.000000    -0.984147       0.623504
# Active_Rate            -0.131956      -0.984147     1.000000      -0.538671
# Recovery_Odds          -0.450787       0.623504    -0.538671       1.000000
#
# [24 rows x 24 columns]

# %%
corr=df_age_recovery.corr()
corr.fillna(value=(0), inplace=True)
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(14, 15))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, cmap="Blues")
    ax.set_title("Correlation Analysis")

# %% [markdown]
# From the correlation heatmap above, we can see that the Recovery odds of Covid-19 has a moderate correlation with GDP of a country as well as the number of cases of Hepatitis B & Measles in the country.
#
# Recovery odds of Covid-19 has no correlation to the size of the country population.
